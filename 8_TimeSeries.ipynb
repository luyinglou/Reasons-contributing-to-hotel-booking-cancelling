# %%
dbutils.fs.refreshMounts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Mounts successfully refreshed.
# Out[1]: True</div>

# %%
display(dbutils.fs.ls('/mnt/s3data'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/s3data/hotel_booking_Indexcleaned.parquet/</td><td>hotel_booking_Indexcleaned.parquet/</td><td>0</td></tr><tr><td>dbfs:/mnt/s3data/hotel_booking_cleaned.parquet/</td><td>hotel_booking_cleaned.parquet/</td><td>0</td></tr><tr><td>dbfs:/mnt/s3data/hotel_booking_cleaned0502.parquet/</td><td>hotel_booking_cleaned0502.parquet/</td><td>0</td></tr><tr><td>dbfs:/mnt/s3data/hotel_booking_indexencoded.parquet/</td><td>hotel_booking_indexencoded.parquet/</td><td>0</td></tr><tr><td>dbfs:/mnt/s3data/hotel_bookings.csv</td><td>hotel_bookings.csv</td><td>16855599</td></tr></tbody></table></div>

# %%
import pandas as pd
hotelDF = spark.read.option("header", True).csv("dbfs:/mnt/s3data/hotel_bookings.csv").toPandas()
display(hotelDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>hotel</th><th>is_canceled</th><th>lead_time</th><th>arrival_date_year</th><th>arrival_date_month</th><th>arrival_date_week_number</th><th>arrival_date_day_of_month</th><th>stays_in_weekend_nights</th><th>stays_in_week_nights</th><th>adults</th><th>children</th><th>babies</th><th>meal</th><th>country</th><th>market_segment</th><th>distribution_channel</th><th>is_repeated_guest</th><th>previous_cancellations</th><th>previous_bookings_not_canceled</th><th>reserved_room_type</th><th>assigned_room_type</th><th>booking_changes</th><th>deposit_type</th><th>agent</th><th>company</th><th>days_in_waiting_list</th><th>customer_type</th><th>adr</th><th>required_car_parking_spaces</th><th>total_of_special_requests</th><th>reservation_status</th><th>reservation_status_date</th></tr></thead><tbody><tr><td>Resort Hotel</td><td>0</td><td>342</td><td>2015</td><td>July</td><td>27</td><td>1</td><td>0</td><td>0</td><td>2</td><td>0</td><td>0</td><td>BB</td><td>PRT</td><td>Direct</td><td>Direct</td><td>0</td><td>0</td><td>0</td><td>C</td><td>C</td><td>3</td><td>No Deposit</td><td>NULL</td><td>NULL</td><td>0</td><td>Transient</td><td>0</td><td>0</td><td>0</td><td>Check-Out</td><td>2015-07-01</td></tr><tr><td>Resort Hotel</td><td>0</td><td>737</td><td>2015</td><td>July</td><td>27</td><td>1</td><td>0</td><td>0</td><td>2</td><td>0</td><td>0</td><td>BB</td><td>PRT</td><td>Direct</td><td>Direct</td><td>0</td><td>0</td><td>0</td><td>C</td><td>C</td><td>4</td><td>No Deposit</td><td>NULL</td><td>NULL</td><td>0</td><td>Transient</td><td>0</td><td>0</td><td>0</td><td>Check-Out</td><td>2015-07-01</td></tr><tr><td>Resort Hotel</td><td>0</td><td>7</td><td>2015</td><td>July</td><td>27</td><td>1</td><td>0</td><td>1</td><td>1</td><td>0</td><td>0</td><td>BB</td><td>GBR</td><td>Direct</td><td>Direct</td><td>0</td><td>0</td><td>0</td><td>A</td><td>C</td><td>0</td><td>No Deposit</td><td>NULL</td><td>NULL</td><td>0</td><td>Transient</td><td>75</td><td>0</td><td>0</td><td>Check-Out</td><td>2015-07-02</td></tr><tr><td>Resort Hotel</td><td>0</td><td>13</td><td>2015</td><td>July</td><td>27</td><td>1</td><td>0</td><td>1</td><td>1</td><td>0</td><td>0</td><td>BB</td><td>GBR</td><td>Corporate</td><td>Corporate</td><td>0</td><td>0</td><td>0</td><td>A</td><td>A</td><td>0</td><td>No Deposit</td><td>304</td><td>NULL</td><td>0</td><td>Transient</td><td>75</td><td>0</td><td>0</td><td>Check-Out</td><td>2015-07-02</td></tr><tr><td>Resort Hotel</td><td>0</td><td>14</td><td>2015</td><td>July</td><td>27</td><td>1</td><td>0</td><td>2</td><td>2</td><td>0</td><td>0</td><td>BB</td><td>GBR</td><td>Online TA</td><td>TA/TO</td><td>0</td><td>0</td><td>0</td><td>A</td><td>A</td><td>0</td><td>No Deposit</td><td>240</td><td>NULL</td><td>0</td><td>Transient</td><td>98</td><td>0</td><td>1</td><td>Check-Out</td><td>2015-07-03</td></tr><tr><td>Resort Hotel</td><td>0</td><td>14</td><td>2015</td><td>July</td><td>27</td><td>1</td><td>0</td><td>2</td><td>2</td><td>0</td><td>0</td><td>BB</td><td>GBR</td><td>Online TA</td><td>TA/TO</td><td>0</td><td>0</td><td>0</td><td>A</td><td>A</td><td>0</td><td>No Deposit</td><td>240</td><td>NULL</td><td>0</td><td>Transient</td><td>98</td><td>0</td><td>1</td><td>Check-Out</td><td>2015-07-03</td></tr><tr><td>Resort Hotel</td><td>0</td><td>0</td><td>2015</td><td>July</td><td>27</td><td>1</td><td>0</td><td>2</td><td>2</td><td>0</td><td>0</td><td>BB</td><td>PRT</td><td>Direct</td><td>Direct</td><td>0</td><td>0</td><td>0</td><td>C</td><td>C</td><td>0</td><td>No Deposit</td><td>NULL</td><td>NULL</td><td>0</td><td>Transient</td><td>107</td><td>0</td><td>0</td><td>Check-Out</td><td>2015-07-03</td></tr><tr><td>Resort Hotel</td><td>0</td><td>9</td><td>2015</td><td>July</td><td>27</td><td>1</td><td>0</td><td>2</td><td>2</td><td>0</td><td>0</td><td>FB</td><td>PRT</td><td>Direct</td><td>Direct</td><td>0</td><td>0</td><td>0</td><td>C</td><td>C</td><td>0</td><td>No Depos ...

# %%
resortDF = hotelDF[hotelDF['hotel']== 'Resort Hotel']
cityDF = hotelDF[hotelDF['hotel']=='City Hotel']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
month_dict = {'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5,
              'June': 6, 'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12 }
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
arrival_month = [month_dict[i] for i in resortDF['arrival_date_month']]
resortDF['arrival_month']=arrival_month
resortDF['arrival_year_month'] = [(str(resortDF['arrival_date_year'][i])+'-'
                                   +str(resortDF['arrival_month'][i])+'-'
                                   +str(resortDF['arrival_date_day_of_month'][i])) for i in range(len(resortDF))]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/tmp/1588526611455-0/PythonShell.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from __future__ import print_function
# /local_disk0/tmp/1588526611455-0/PythonShell.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import linecache
# </div>

# %%
resortDF['is_canceled'] = resortDF['is_canceled'].astype('int')
booking_num = pd.DataFrame(resortDF['is_canceled'].groupby(by=resortDF['arrival_year_month']).count())
cancel_num = pd.DataFrame(resortDF['is_canceled'].groupby(by=resortDF['arrival_year_month']).sum())
booking_num['is_canceled'] = booking_num['is_canceled'].astype('int')
cancel_num['is_canceled'] = cancel_num['is_canceled'].astype('int')
booking_num = booking_num.reset_index()
cancel_num = cancel_num.reset_index()
booking_num['cancel_num']=cancel_num['is_canceled']
booking_num['cancel_rate']=booking_num['cancel_num']/booking_num['is_canceled']
booking_num = booking_num.sort_values(by='arrival_year_month')
booking_num['cancel_rate'] = [ round(i,3) for i in booking_num['cancel_rate'] ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/tmp/1588526611455-0/PythonShell.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from __future__ import absolute_import
# </div>

# %% [markdown]
# #### Predictions for the cancellation rate of Resort Hotel

# %%
import logging
logger = spark._jvm.org.apache.log4j
logging.getLogger("py4j").setLevel(logging.ERROR)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from datetime import datetime
from fbprophet import Prophet
# convert to date type
booking_num['arrival_year_month'] = booking_num['arrival_year_month'].apply(lambda x:datetime.strptime(x, '%Y-%m-%d'))
# extract the date and cancel_rate columns
booking_num = booking_num.iloc[:,[0,3]]
# rename to fit Prophet
booking_num.columns = ['ds','y']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
booking_num.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ds</th>
#       <th>y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2015-10-01</td>
#       <td>0.093</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2015-10-10</td>
#       <td>0.338</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2015-10-11</td>
#       <td>0.140</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2015-10-12</td>
#       <td>0.066</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2015-10-13</td>
#       <td>0.029</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
p = Prophet()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
p.fit(booking_num)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Out[20]: &lt;fbprophet.forecaster.Prophet at 0x7f31fd93c128&gt;</div>

# %%
future = p.make_future_dataframe(periods=365)
future.tail()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1153</th>
#       <td>2018-08-27</td>
#     </tr>
#     <tr>
#       <th>1154</th>
#       <td>2018-08-28</td>
#     </tr>
#     <tr>
#       <th>1155</th>
#       <td>2018-08-29</td>
#     </tr>
#     <tr>
#       <th>1156</th>
#       <td>2018-08-30</td>
#     </tr>
#     <tr>
#       <th>1157</th>
#       <td>2018-08-31</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# forecast the next year's cancellation rate with an confidence interval
forecast = p.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ds</th>
#       <th>yhat</th>
#       <th>yhat_lower</th>
#       <th>yhat_upper</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1153</th>
#       <td>2018-08-27</td>
#       <td>0.422803</td>
#       <td>0.281689</td>
#       <td>0.559792</td>
#     </tr>
#     <tr>
#       <th>1154</th>
#       <td>2018-08-28</td>
#       <td>0.396896</td>
#       <td>0.254740</td>
#       <td>0.537655</td>
#     </tr>
#     <tr>
#       <th>1155</th>
#       <td>2018-08-29</td>
#       <td>0.403910</td>
#       <td>0.258092</td>
#       <td>0.547875</td>
#     </tr>
#     <tr>
#       <th>1156</th>
#       <td>2018-08-30</td>
#       <td>0.407821</td>
#       <td>0.262590</td>
#       <td>0.551147</td>
#     </tr>
#     <tr>
#       <th>1157</th>
#       <td>2018-08-31</td>
#       <td>0.464327</td>
#       <td>0.309484</td>
#       <td>0.602095</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# explore the seasonality for year, month, week
fig2 = p.plot_components(forecast)  
display()

# %%
p.plot(forecast)
display()

# %% [markdown]
# #### The trend of cancellation rate

# %%
x = np.array(range(len(booking_num)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
plt.figure(figsize=(10, 6))
import matplotlib.pyplot as plt
x = np.array(range(len(booking_num)))
y = booking_num['cancel_rate']
labels = np.array(booking_num['arrival_year_month'])
plt.plot(x, y)
plt.xlabel("Time")
plt.xticks(x, labels)
plt.ylabel("Cancel rate")
plt.title('Cancel rate of resort hotel')
display()

# %%
arrival_month = [month_dict[i] for i in cityDF ['arrival_date_month']]
cityDF['arrival_month']=arrival_month
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/tmp/1588441583775-0/PythonShell.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from __future__ import print_function
# </div>

# %%
cityDF = hotelDF[hotelDF['hotel']=='City Hotel']
arrival_month = [month_dict[i] for i in cityDF ['arrival_date_month']]
cityDF['arrival_month']=arrival_month
cityDF ['arrival_year_month'] = [(str(pd.array(cityDF['arrival_date_year'])[i])+'-'
                                   +str(pd.array(cityDF['arrival_month'])[i])+'-'
                                   +str(pd.array(cityDF['arrival_date_day_of_month'])[i])) for i in range(len(cityDF))]
cityDF['is_canceled'] = cityDF['is_canceled'].astype('int')
booking_num2 = pd.DataFrame(cityDF['is_canceled'].groupby(by=cityDF['arrival_year_month']).count())
cancel_num2 = pd.DataFrame(cityDF['is_canceled'].groupby(by=cityDF['arrival_year_month']).sum())
booking_num2['is_canceled'] = booking_num2['is_canceled'].astype('int')
cancel_num2['is_canceled'] = cancel_num2['is_canceled'].astype('int')
booking_num2 = booking_num2.reset_index()
cancel_num2 = cancel_num2.reset_index()
booking_num2['cancel_num']=cancel_num2['is_canceled']
booking_num2['cancel_rate']=booking_num2['cancel_num']/booking_num2['is_canceled']
booking_num2 = booking_num2.sort_values(by='arrival_year_month')
booking_num2['cancel_rate'] = [ round(i,3) for i in booking_num2['cancel_rate'] ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/tmp/1588470198593-0/PythonShell.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /local_disk0/tmp/1588470198593-0/PythonShell.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import os
# /local_disk0/tmp/1588470198593-0/PythonShell.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import pickle
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(15, 8))
x = np.array(range(len(booking_num2)))
y = booking_num2['cancel_rate']
labels = np.array(range(len(booking_num2)))
plt.plot(x, y,color='#0e540e')
plt.xlabel("Time")
plt.xticks(x, labels)
plt.ylabel("Cancel rate")
plt.title('Cancel rate of city hotel')
display()

# %% [markdown]
# #### Other: LSTM and CNN in cancellation rate forecasting

# %%
time = np.array(range(len(booking_num2)))
series = booking_num2['cancel_rate']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# There are 10 years data of 3650 data points in series
split_time = 650
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]

window_size = 30
batch_size = 32
shuffle_buffer_size = 100
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import tensorflow as tf
tf.keras.backend.clear_session()
tf.random.set_seed(51)
np.random.seed(51)

train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=32, kernel_size=5,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[None, 1]),
  tf.keras.layers.LSTM(32, return_sequences=True),
  tf.keras.layers.LSTM(32, return_sequences=True),
  tf.keras.layers.Dense(20, activation="relu"),
  tf.keras.layers.Dense(10, activation="relu"),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 400)
])
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))
optimizer = tf.keras.optimizers.SGD(lr=1e-8, momentum=0.9)
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])
history = model.fit(train_set, epochs=50,callbacks=[lr_schedule])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Epoch 1/50
# 20/20 [==============================] - 4s 201ms/step - loss: 3.9263 - mae: 4.4201
# Epoch 2/50
# 20/20 [==============================] - 1s 32ms/step - loss: 3.3429 - mae: 3.8287
# Epoch 3/50
# 20/20 [==============================] - 1s 33ms/step - loss: 2.6648 - mae: 3.1438
# Epoch 4/50
# 20/20 [==============================] - 1s 33ms/step - loss: 2.0134 - mae: 2.4875
# Epoch 5/50
# 20/20 [==============================] - 1s 33ms/step - loss: 1.4685 - mae: 1.9313
# Epoch 6/50
# 20/20 [==============================] - 1s 34ms/step - loss: 1.0983 - mae: 1.5408
# Epoch 7/50
# 20/20 [==============================] - 1s 36ms/step - loss: 0.8969 - mae: 1.3354
# Epoch 8/50
# 20/20 [==============================] - 1s 38ms/step - loss: 0.8137 - mae: 1.2503
# Epoch 9/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.7833 - mae: 1.2074
# Epoch 10/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.7404 - mae: 1.1707
# Epoch 11/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.7096 - mae: 1.1326
# Epoch 12/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.6685 - mae: 1.0925
# Epoch 13/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.6303 - mae: 1.0494
# Epoch 14/50
# 20/20 [==============================] - 1s 32ms/step - loss: 0.5894 - mae: 1.0019
# Epoch 15/50
# 20/20 [==============================] - 1s 34ms/step - loss: 0.5460 - mae: 0.9506
#
# *** WARNING: skipped 32932 bytes of output ***
#
# 20/20 [==============================] - 1s 33ms/step - loss: 0.1802 - mae: 0.4724
# Epoch 37/50
# 20/20 [==============================] - 1s 35ms/step - loss: 0.1481 - mae: 0.4246
# Epoch 38/50
# 20/20 [==============================] - 1s 33ms/step - loss: 0.1425 - mae: 0.4113
# Epoch 39/50
#  7/20 [=

# %%
def model_forecast(model, series, window_size):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size))
    ds = ds.batch(32).prefetch(1)
    forecast = model.predict(ds)
    return forecast
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rnn_forecast = model_forecast(model, series[split_time:,np.newaxis], window_size)
rnn_forecast = rnn_forecast[0:-1, -1, 0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
new_time_valid = time[(split_time+30):]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
new_x_valid=series[(split_time+30):]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
plt.figure(figsize=(10, 6))
plt.plot(new_time_valid, new_x_valid)
plt.plot(new_time_valid, rnn_forecast)
display()

# %%
try:
  dbutils.fs.unmount('/mnt/s3data') 
except:
  print("/mnt/s3data has been unmounted")
